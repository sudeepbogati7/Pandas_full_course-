# %% [markdown]
#  # Read CSV

# %%
import pandas as pd

# %%
csv_1 = pd.read_csv("test.csv")  #reads the csv file
csv_1
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
csv_2 = pd.read_csv("test.csv",nrows= 100) #to get n number of rows
csv_2
# Out:
#     Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0   2021                     Level 1                99999
# 1   2021                     Level 1                99999
# 2   2021                     Level 1                99999
# 3   2021                     Level 1                99999
# 4   2021                     Level 1                99999
# ..   ...                         ...                  ...
# 95  2021                     Level 4                AA111
# 96  2021                     Level 4                AA111
# 97  2021                     Level 4                AA111
# 98  2021                     Level 4                AA111
# 99  2021                     Level 4                AA111
#
#               Industry_name_NZSIOC               Units Variable_code  \
# 0                   All industries  Dollars (millions)           H01
# 1                   All industries  Dollars (millions)           H04
# ...

# %%
csv_4 = pd.read_csv("test.csv",nrows= 10) #to get n number of rows
csv_4
# Out:
#    Year Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0  2021                     Level 1                 99999
# 1  2021                     Level 1                 99999
# 2  2021                     Level 1                 99999
# 3  2021                     Level 1                 99999
# 4  2021                     Level 1                 99999
# 5  2021                     Level 1                 99999
# 6  2021                     Level 1                 99999
# 7  2021                     Level 1                 99999
# 8  2021                     Level 1                 99999
# 9  2021                     Level 1                 99999
#
#   Industry_name_NZSIOC               Units Variable_code  \
# 0       All industries  Dollars (millions)           H01
# 1       All industries  Dollars (millions)           H04
# 2       All industries  Dollars (millions)           H05
# 3       All industries  Dollars (millions)           H07
# ...

# %%
csv_4 = pd.read_csv("test.csv", usecols= ["Industry_code_ANZSIC06"]) #to get specific column
csv_4
# Out:
#                                   Industry_code_ANZSIC06
# 0      ANZSIC06 divisions A-S (excluding classes K633...
# 1      ANZSIC06 divisions A-S (excluding classes K633...
# 2      ANZSIC06 divisions A-S (excluding classes K633...
# 3      ANZSIC06 divisions A-S (excluding classes K633...
# 4      ANZSIC06 divisions A-S (excluding classes K633...
# ...                                                  ...
# 41710  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 41711  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 41712  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 41713  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 41714  ANZSIC06 groups C111, C112, C113, C114, C115, ...
#
# [41715 rows x 1 columns]

# %%
csv_5 = pd.read_csv("test.csv", usecols= ["Industry_code_ANZSIC06","Year","Units"]) #to get specific columns
csv_5
# Out:
#        Year               Units  \
# 0      2021  Dollars (millions)
# 1      2021  Dollars (millions)
# 2      2021  Dollars (millions)
# 3      2021  Dollars (millions)
# 4      2021  Dollars (millions)
# ...     ...                 ...
# 41710  2013          Percentage
# 41711  2013          Percentage
# 41712  2013          Percentage
# 41713  2013          Percentage
# 41714  2013          Percentage
#
#                                   Industry_code_ANZSIC06
# 0      ANZSIC06 divisions A-S (excluding classes K633...
# 1      ANZSIC06 divisions A-S (excluding classes K633...
# 2      ANZSIC06 divisions A-S (excluding classes K633...
# 3      ANZSIC06 divisions A-S (excluding classes K633...
# 4      ANZSIC06 divisions A-S (excluding classes K633...
# ...                                                  ...
# 41710  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 41711  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# ...

# %% [markdown]
# ### get specific columns by passing index number

# %%
csv_6 = pd.read_csv("test.csv", usecols= [0,3,5,4,5]) #using index number 
csv_6
# Out:
#        Year        Industry_name_NZSIOC               Units Variable_code
# 0      2021              All industries  Dollars (millions)           H01
# 1      2021              All industries  Dollars (millions)           H04
# 2      2021              All industries  Dollars (millions)           H05
# 3      2021              All industries  Dollars (millions)           H07
# 4      2021              All industries  Dollars (millions)           H08
# ...     ...                         ...                 ...           ...
# 41710  2013  Food product manufacturing          Percentage           H37
# 41711  2013  Food product manufacturing          Percentage           H38
# 41712  2013  Food product manufacturing          Percentage           H39
# 41713  2013  Food product manufacturing          Percentage           H40
# 41714  2013  Food product manufacturing          Percentage           H41
#
# [41715 rows x 4 columns]

# %% [markdown]
# ## Skip a specific row

# %%
csv_4 = pd.read_csv("test.csv",nrows= 10, skiprows = [0,1]) 
csv_4
# Out:
#    2021  Level 1  99999  All industries  Dollars (millions)  H04  \
# 0  2021  Level 1  99999  All industries  Dollars (millions)  H05
# 1  2021  Level 1  99999  All industries  Dollars (millions)  H07
# 2  2021  Level 1  99999  All industries  Dollars (millions)  H08
# 3  2021  Level 1  99999  All industries  Dollars (millions)  H09
# 4  2021  Level 1  99999  All industries  Dollars (millions)  H10
# 5  2021  Level 1  99999  All industries  Dollars (millions)  H11
# 6  2021  Level 1  99999  All industries  Dollars (millions)  H12
# 7  2021  Level 1  99999  All industries  Dollars (millions)  H13
# 8  2021  Level 1  99999  All industries  Dollars (millions)  H14
# 9  2021  Level 1  99999  All industries  Dollars (millions)  H19
#
#      Sales, government funding, grants and subsidies  Financial performance  \
# 0                  Interest, dividends and donations  Financial performance
# 1                               Non-operating income  Financial performance
# ...

# %% [markdown]
# # make index of a column

# %%
csv_7 = pd.read_csv("test.csv", nrows=5, index_col = "Year") #changes the index to "Year" column
csv_7
# Out:
#      Industry_aggregation_NZSIOC  Industry_code_NZSIOC Industry_name_NZSIOC  \
# Year
# 2021                     Level 1                 99999       All industries
# 2021                     Level 1                 99999       All industries
# 2021                     Level 1                 99999       All industries
# 2021                     Level 1                 99999       All industries
# 2021                     Level 1                 99999       All industries
#
#                    Units Variable_code  \
# Year
# 2021  Dollars (millions)           H01
# 2021  Dollars (millions)           H04
# 2021  Dollars (millions)           H05
# 2021  Dollars (millions)           H07
# 2021  Dollars (millions)           H08
#
#                                         Variable_name      Variable_category  \
# Year
# 2021                                     Total income  Financial performance
# 2021  Sales, government funding, grants and subsidies  Financial performance
# ...

# %% [markdown]
# ### Change the header

# %%
csv_8 = pd.read_csv("test.csv", nrows=5, header = 5) #header is changed .... the fifth row is header now !
csv_8
# Out:
#    2021  Level 1  99999  All industries  Dollars (millions)  H08  \
# 0  2021  Level 1  99999  All industries  Dollars (millions)  H09
# 1  2021  Level 1  99999  All industries  Dollars (millions)  H10
# 2  2021  Level 1  99999  All industries  Dollars (millions)  H11
# 3  2021  Level 1  99999  All industries  Dollars (millions)  H12
# 4  2021  Level 1  99999  All industries  Dollars (millions)  H13
#
#           Total expenditure  Financial performance  654,404  \
# 0    Interest and donations  Financial performance   26,138
# 1            Indirect taxes  Financial performance    6,991
# 2              Depreciation  Financial performance   27,801
# 3   Salaries and wages paid  Financial performance  123,620
# 4  Redundancy and severance  Financial performance      275
#
#   ANZSIC06 divisions A-S (excluding classes K6330, L6711, O7552, O760, O771, O772, S9540, S9601, S9602, and S9603)
# 0  ANZSIC06 divisions A-S (excluding classes K633...
# ...

# %% [markdown]
# # Add or changes custom heading (name function)

# %%
csv_9 = pd.read_csv("test.csv", nrows=5, names = ["a","b","c","d","e","f","g","h","i","j"]) 
csv_9
# Out:
#       a                            b                     c  \
# 0  Year  Industry_aggregation_NZSIOC  Industry_code_NZSIOC
# 1  2021                      Level 1                 99999
# 2  2021                      Level 1                 99999
# 3  2021                      Level 1                 99999
# 4  2021                      Level 1                 99999
#
#                       d                   e              f  \
# 0  Industry_name_NZSIOC               Units  Variable_code
# 1        All industries  Dollars (millions)            H01
# 2        All industries  Dollars (millions)            H04
# 3        All industries  Dollars (millions)            H05
# 4        All industries  Dollars (millions)            H07
#
#                                                  g                      h  \
# 0                                    Variable_name      Variable_category
# 1                                     Total income  Financial performance
# ...

# %% [markdown]
# ## Use of prefix in the heading

# %%
csv_10 = pd.read_csv("test.csv", nrows=5, , header = None, prefix = "col")
csv_10
# Out:
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_10844\2901973529.py", line 1
#     csv_10 = pd.read_csv("test.csv", nrows=5, , header = None, prefix = "col")
#                                               ^
# SyntaxError: invalid syntax
